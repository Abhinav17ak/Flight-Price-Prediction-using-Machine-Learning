# %% [markdown]
# ## Flight Price Prediction Using different models

# %%
## importing necessary packages 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Importing dataset

# %%
train_data = pd.read_excel("Data_Train.xlsx")

# %%
train_data.head(6)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
# 5     SpiceJet      24/06/2019   Kolkata    Banglore              CCU → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302
# ...

# %%
train_data.tail(6)
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 10677     SpiceJet      21/05/2019  Banglore       Delhi
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time Arrival_Time Duration Total_Stops  \
# 10677              BLR → DEL    05:55        08:35   2h 40m    non-stop
# 10678              CCU → BLR    19:55        22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45        23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20        11:20       3h    non-stop
# 10681              BLR → DEL    11:30        14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55        19:15   8h 20m     2 stops
#
#                     Additional_Info  Price
# ...

# %% [markdown]
# ## 2)   Finding missing values

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
train_data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
train_data['Total_Stops'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10678    False
# 10679    False
# 10680    False
# 10681    False
# 10682    False
# Name: Total_Stops, Length: 10683, dtype: bool

# %%
train_data.dropna(inplace=True)

# %%
train_data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
train_data.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %% [markdown]
# ## 3.  we have to do Data Preprocessing and extracting the  derived attributes from  the column "Date_of_Journey"

# %%
data = train_data.copy()

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
data.head(5)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
data.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %% [markdown]
# #### Date_of_Journey has  Object data type.
#      So converting object data type to datetime dtype.

# %%
def change_into_Datetime(col):
    data[col] = pd.to_datetime(data[col])

# %%
import warnings 
from warnings import filterwarnings
filterwarnings("ignore")

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
for feature in ['Dep_Time', 'Arrival_Time' , 'Date_of_Journey']:
    change_into_Datetime(feature)

# %%
data.dtypes
# Out:
# Airline                    object
# Date_of_Journey    datetime64[ns]
# Source                     object
# Destination                object
# Route                      object
# Dep_Time           datetime64[ns]
# Arrival_Time       datetime64[ns]
# Duration                   object
# Total_Stops                object
# Additional_Info            object
# Price                       int64
# dtype: object

# %%
data["Journey_day"] = data['Date_of_Journey'].dt.day

# %%
data["Journey_month"] = data['Date_of_Journey'].dt.month

# %%
data["Journey_year"] = data['Date_of_Journey'].dt.year

# %%
data.head(5)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-05-12   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-03-01  Banglore   New Delhi        BLR → NAG → DEL
#
#              Dep_Time        Arrival_Time Duration Total_Stops  \
# 0 2025-03-06 22:20:00 2025-03-22 01:10:00   2h 50m    non-stop
# 1 2025-03-06 05:50:00 2025-03-06 13:15:00   7h 25m     2 stops
# 2 2025-03-06 09:25:00 2025-06-10 04:25:00      19h     2 stops
# 3 2025-03-06 18:05:00 2025-03-06 23:30:00   5h 25m      1 stop
# 4 2025-03-06 16:50:00 2025-03-06 21:35:00   4h 45m      1 stop
#
#   Additional_Info  Price  Journey_day  Journey_month  Journey_year
# ...

# %% [markdown]
# ## 4. Preprocessing Dep_Time & Arrival_Time and Extracting Derived Attributes.

# %%
def extract_hour_min(df , col):
    df[col+"_hour"] = df[col].dt.hour
    df[col+"_minute"] = df[col].dt.minute
    return df.head(3)

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price', 'Journey_day', 'Journey_month',
#        'Journey_year'],
#       dtype='object')

# %%
extract_hour_min(data , "Dep_Time")
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
#
#              Dep_Time        Arrival_Time Duration Total_Stops  \
# 0 2025-03-06 22:20:00 2025-03-22 01:10:00   2h 50m    non-stop
# 1 2025-03-06 05:50:00 2025-03-06 13:15:00   7h 25m     2 stops
# 2 2025-03-06 09:25:00 2025-06-10 04:25:00      19h     2 stops
#
#   Additional_Info  Price  Journey_day  Journey_month  Journey_year  \
# 0         No info   3897           24              3          2019
# 1         No info   7662            1              5          2019
# 2         No info  13882            9              6          2019
#
#    Dep_Time_hour  Dep_Time_minute
# 0             22               20
# 1              5               50
# ...

# %%
extract_hour_min(data , "Arrival_Time")
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
#
#              Dep_Time        Arrival_Time Duration Total_Stops  \
# 0 2025-03-06 22:20:00 2025-03-22 01:10:00   2h 50m    non-stop
# 1 2025-03-06 05:50:00 2025-03-06 13:15:00   7h 25m     2 stops
# 2 2025-03-06 09:25:00 2025-06-10 04:25:00      19h     2 stops
#
#   Additional_Info  Price  Journey_day  Journey_month  Journey_year  \
# 0         No info   3897           24              3          2019
# 1         No info   7662            1              5          2019
# 2         No info  13882            9              6          2019
#
#    Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  Arrival_Time_minute
# ...

# %% [markdown]
# ## Derived attributes have been extracted from ['Arrival_Time', 'Dep_Time'], so these features are dropped.

# %%
cols_to_drop = ['Arrival_Time' , "Dep_Time"]

data.drop(cols_to_drop , axis=1 , inplace=True )

# %%
data.head(3)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
#
#   Duration Total_Stops Additional_Info  Price  Journey_day  Journey_month  \
# 0   2h 50m    non-stop         No info   3897           24              3
# 1   7h 25m     2 stops         No info   7662            1              5
# 2      19h     2 stops         No info  13882            9              6
#
#    Journey_year  Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  \
# 0          2019             22               20                  1
# 1          2019              5               50                 13
# 2          2019              9               25                  4
#
#    Arrival_Time_minute
# 0                   10
# 1                   15
# ...

# %% [markdown]
# ##  Analyze the time period when most flights take off.

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Duration', 'Total_Stops', 'Additional_Info', 'Price', 'Journey_day',
#        'Journey_month', 'Journey_year', 'Dep_Time_hour', 'Dep_Time_minute',
#        'Arrival_Time_hour', 'Arrival_Time_minute'],
#       dtype='object')

# %%
#### Converting the flight Dep_Time into appropriate time categories such as midnight, morning, afternoon, and evening.

def flight_dep_time(x):
   
    
    if (x>4) and (x<=8):
        return "Early Morning"
    
    elif (x>8) and (x<=12):
        return "Morning"
    
    elif (x>12) and (x<=16):
        return "Noon"
    
    elif (x>16) and (x<=20):
        return "Evening"
    
    elif (x>20) and (x<=24):
        return "Night"
    
    else:
        return "late night"

# %%
data['Dep_Time_hour'].apply(flight_dep_time).value_counts().plot(kind="bar" , color="g")
# Out:
# <Axes: xlabel='Dep_Time_hour'>

# %% [markdown]
# ## Preprocess the Duration feature and extract valuable insights from it.

# %% [markdown]
# ### Let's apply preprocessing to the Duration column:

# %%
def preprocess_duration(x):
    if 'h' not in x:
        x = '0h' + ' ' + x
    elif 'm' not in x:
        x = x + ' ' +'0m'
        
    return x

# %%
data['Duration'] = data['Duration'].apply(preprocess_duration)

# %%
data['Duration']
# Out:
# 0        2h 50m
# 1        7h 25m
# 2        19h 0m
# 3        5h 25m
# 4        4h 45m
#           ...
# 10678    2h 30m
# 10679    2h 35m
# 10680     3h 0m
# 10681    2h 40m
# 10682    8h 20m
# Name: Duration, Length: 10682, dtype: object

# %% [markdown]
# ## we will extract the hours and minutes from the duration.

# %%
data['Duration_hours'] = data['Duration'].apply(lambda x : int(x.split(' ')[0][0:-1]))
data['Duration_mins'] = data['Duration'].apply(lambda x : int(x.split(' ')[1][0:-1]))

# %%
data.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1  Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Duration Total_Stops Additional_Info  Price  Journey_day  Journey_month  \
# 0   2h 50m    non-stop         No info   3897           24              3
# 1   7h 25m     2 stops         No info   7662            1              5
#
#    Journey_year  Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  \
# 0          2019             22               20                  1
# 1          2019              5               50                 13
#
#    Arrival_Time_minute  Duration_hours  Duration_mins
# 0                   10               2             50
# 1                   15               7             25

# %% [markdown]
# ## Let’s investigate if the Duration influences the Price in any way

# %%
data['Duration']
# Out:
# 0        2h 50m
# 1        7h 25m
# 2        19h 0m
# 3        5h 25m
# 4        4h 45m
#           ...
# 10678    2h 30m
# 10679    2h 35m
# 10680     3h 0m
# 10681    2h 40m
# 10682    8h 20m
# Name: Duration, Length: 10682, dtype: object

# %% [markdown]
# ## Convert the duration into the total duration in minutes.

# %%
data['Duration_total_mins'] = data['Duration'].str.replace('h' ,"*60").str.replace(' ' , '+').str.replace('m' , "*1").apply(eval)

# %%
data['Duration_total_mins']
# Out:
# 0         170
# 1         445
# 2        1140
# 3         325
# 4         285
#          ...
# 10678     150
# 10679     155
# 10680     180
# 10681     160
# 10682     500
# Name: Duration_total_mins, Length: 10682, dtype: int64

# %%
sns.scatterplot(x="Duration_total_mins" , y="Price" , data=data)
# Out:
# <Axes: xlabel='Duration_total_mins', ylabel='Price'>

# %% [markdown]
# ## Does the number of total stops influence the price?

# %%
sns.scatterplot(x="Duration_total_mins" , y="Price" , hue="Total_Stops", data=data)
# Out:
# <Axes: xlabel='Duration_total_mins', ylabel='Price'>

# %%
sns.boxplot(y='Price' , x='Airline' , data=data.sort_values('Price' , ascending=False))
plt.xticks(rotation="vertical")
plt.show()

# %% [markdown]
# ##  Performing one-hot encoding on the data.

# %%
cat_col = [col for col in data.columns if data[col].dtype=="object"]

# %%
num_col = [col for col in data.columns if data[col].dtype!="object"]

# %% [markdown]
# ## Handling Categorical Data
# Using two basic encoding techniques to convert categorical data into a numerical format:
#
# Nominal Data: Data without any specific order. In this case, OneHotEncoder is applied.
# Ordinal Data: Data that has a specific order. LabelEncoder is used for this type of data.

# %%
cat_col
# Out:
# ['Airline',
#  'Source',
#  'Destination',
#  'Route',
#  'Duration',
#  'Total_Stops',
#  'Additional_Info']

# %% [markdown]
# ## Applying One-hot encoding

# %%
data['Source'].unique()
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %%
data['Source'].apply(lambda x : 1 if x=='Banglore' else 0)
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 10678    0
# 10679    0
# 10680    1
# 10681    1
# 10682    0
# Name: Source, Length: 10682, dtype: int64

# %% [markdown]
# ##  This is a manual way of one-hot encoding, which converts categorical values into separate binary columns.
#  --> It helps machine learning models interpret categorical data.

# %%
for sub_category in data['Source'].unique():
    data['Source_'+sub_category] = data['Source'].apply(lambda x : 1 if x==sub_category else 0)

# %%
data.head(3)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
#
#   Duration Total_Stops Additional_Info  Price  Journey_day  ...  \
# 0   2h 50m    non-stop         No info   3897           24  ...
# 1   7h 25m     2 stops         No info   7662            1  ...
# 2   19h 0m     2 stops         No info  13882            9  ...
#
#    Arrival_Time_hour  Arrival_Time_minute  Duration_hours  Duration_mins  \
# 0                  1                   10               2             50
# 1                 13                   15               7             25
# 2                  4                   25              19              0
#
#    Duration_total_mins  Source_Banglore  Source_Kolkata  Source_Delhi  \
# ...

# %% [markdown]
# ## Let's apply target-guided encoding on the data.
# While one-hot encoding can be used, it may lead to the curse of dimensionality if there are many sub-categories. In such cases, we’ll use Target Guided Mean Encoding to avoid this issue.

# %%
cat_col
# Out:
# ['Airline',
#  'Source',
#  'Destination',
#  'Route',
#  'Duration',
#  'Total_Stops',
#  'Additional_Info']

# %%
data.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1  Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Duration Total_Stops Additional_Info  Price  Journey_day  ...  \
# 0   2h 50m    non-stop         No info   3897           24  ...
# 1   7h 25m     2 stops         No info   7662            1  ...
#
#    Arrival_Time_hour  Arrival_Time_minute  Duration_hours  Duration_mins  \
# 0                  1                   10               2             50
# 1                 13                   15               7             25
#
#    Duration_total_mins  Source_Banglore  Source_Kolkata  Source_Delhi  \
# 0                  170                1               0             0
# 1                  445                0               1             0
#
#    Source_Chennai  Source_Mumbai
# 0               0              0
# 1               0              0
#
# ...

# %%
#  check  number of unique values (distinct categories) in the 'Airline' column

# %%
data['Airline'].nunique()
# Out:
# 12

# %% [markdown]
# ### Calculating the average prices for each airline.

# %%
data.groupby(['Airline'])['Price'].mean().sort_values()
# Out:
# Airline
# Trujet                                4140.000000
# SpiceJet                              4338.284841
# Air Asia                              5590.260188
# IndiGo                                5673.682903
# GoAir                                 5861.056701
# Vistara                               7796.348643
# Vistara Premium economy               8962.333333
# Air India                             9612.427756
# Multiple carriers                    10902.678094
# Multiple carriers Premium economy    11418.846154
# Jet Airways                          11643.923357
# Jet Airways Business                 58358.666667
# Name: Price, dtype: float64

# %%
airlines = data.groupby(['Airline'])['Price'].mean().sort_values().index

#  Airlines will contain a sorted list of airline names based on their average price.

# %%
dict_airlines = {key:index for index , key in enumerate(airlines , 0)}

# Why Use This?
# Converts categorical airline names into numerical indices (useful for ML models).
# Helps in feature encoding for algorithms that don't handle categorical data directly.
# Makes it easy to map airlines to their rank based on ticket price.

# %%
dict_airlines
# Out:
# {'Trujet': 0,
#  'SpiceJet': 1,
#  'Air Asia': 2,
#  'IndiGo': 3,
#  'GoAir': 4,
#  'Vistara': 5,
#  'Vistara Premium economy': 6,
#  'Air India': 7,
#  'Multiple carriers': 8,
#  'Multiple carriers Premium economy': 9,
#  'Jet Airways': 10,
#  'Jet Airways Business': 11}

# %%
data['Airline'] = data['Airline'].map(dict_airlines)

# %%
data['Airline']
# Out:
# 0         3
# 1         7
# 2        10
# 3         3
# 4         3
#          ..
# 10678     2
# 10679     7
# 10680    10
# 10681     5
# 10682     7
# Name: Airline, Length: 10682, dtype: int64

# %%
data.head(5)
# Out:
#    Airline Date_of_Journey    Source Destination                  Route  \
# 0        3      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1        7      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2       10      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
# 3        3      2019-05-12   Kolkata    Banglore        CCU → NAG → BLR
# 4        3      2019-03-01  Banglore   New Delhi        BLR → NAG → DEL
#
#   Duration Total_Stops Additional_Info  Price  Journey_day  ...  \
# 0   2h 50m    non-stop         No info   3897           24  ...
# 1   7h 25m     2 stops         No info   7662            1  ...
# 2   19h 0m     2 stops         No info  13882            9  ...
# 3   5h 25m      1 stop         No info   6218           12  ...
# 4   4h 45m      1 stop         No info  13302            1  ...
#
#    Arrival_Time_hour  Arrival_Time_minute  Duration_hours  Duration_mins  \
# ...

# %%
data['Destination'].unique()
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#       dtype=object)

# %%
data['Destination'].replace('New Delhi' , 'Delhi' , inplace=True)

# %%
data['Destination'].unique()
# Out:
# array(['Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Hyderabad'],
#       dtype=object)

# %%
dest = data.groupby(['Destination'])['Price'].mean().sort_values().index

# %%
dest
# Out:
# Index(['Kolkata', 'Hyderabad', 'Delhi', 'Banglore', 'Cochin'], dtype='object', name='Destination')

# %%
dict_dest = {key:index for index , key in enumerate(dest , 0)}

# %%
dict_dest
# Out:
# {'Kolkata': 0, 'Hyderabad': 1, 'Delhi': 2, 'Banglore': 3, 'Cochin': 4}

# %%
data['Destination'] = data['Destination'].map(dict_dest)

# %%
data['Destination']
# Out:
# 0        2
# 1        3
# 2        4
# 3        3
# 4        2
#         ..
# 10678    3
# 10679    3
# 10680    2
# 10681    2
# 10682    4
# Name: Destination, Length: 10682, dtype: int64

# %%
data.head(3)
# Out:
#    Airline Date_of_Journey    Source  Destination                  Route  \
# 0        3      2019-03-24  Banglore            2              BLR → DEL
# 1        7      2019-05-01   Kolkata            3  CCU → IXR → BBI → BLR
# 2       10      2019-06-09     Delhi            4  DEL → LKO → BOM → COK
#
#   Duration Total_Stops Additional_Info  Price  Journey_day  ...  \
# 0   2h 50m    non-stop         No info   3897           24  ...
# 1   7h 25m     2 stops         No info   7662            1  ...
# 2   19h 0m     2 stops         No info  13882            9  ...
#
#    Arrival_Time_hour  Arrival_Time_minute  Duration_hours  Duration_mins  \
# 0                  1                   10               2             50
# 1                 13                   15               7             25
# 2                  4                   25              19              0
#
#    Duration_total_mins  Source_Banglore  Source_Kolkata  Source_Delhi  \
# ...

# %% [markdown]
# ## Apply Manual Label Encoding to the Data.

# %%
data.head(3)
# Out:
#    Airline Date_of_Journey    Source  Destination                  Route  \
# 0        3      2019-03-24  Banglore            2              BLR → DEL
# 1        7      2019-05-01   Kolkata            3  CCU → IXR → BBI → BLR
# 2       10      2019-06-09     Delhi            4  DEL → LKO → BOM → COK
#
#   Duration Total_Stops Additional_Info  Price  Journey_day  ...  \
# 0   2h 50m    non-stop         No info   3897           24  ...
# 1   7h 25m     2 stops         No info   7662            1  ...
# 2   19h 0m     2 stops         No info  13882            9  ...
#
#    Arrival_Time_hour  Arrival_Time_minute  Duration_hours  Duration_mins  \
# 0                  1                   10               2             50
# 1                 13                   15               7             25
# 2                  4                   25              19              0
#
#    Duration_total_mins  Source_Banglore  Source_Kolkata  Source_Delhi  \
# ...

# %%
data['Total_Stops']
# Out:
# 0        non-stop
# 1         2 stops
# 2         2 stops
# 3          1 stop
# 4          1 stop
#            ...
# 10678    non-stop
# 10679    non-stop
# 10680    non-stop
# 10681    non-stop
# 10682     2 stops
# Name: Total_Stops, Length: 10682, dtype: object

# %%
data['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', '4 stops'],
#       dtype=object)

# %% [markdown]
# ## Converts categorical stop data into a numerical format required for ML models.
#  ===>  Maintains the natural order (more stops mean a higher number).
#      ====> Simple and efficient way to encode ordinal categorical data.

# %%
stop = {'non-stop':0, '2 stops':2, '1 stop':1, '3 stops':3, '4 stops':4}

# %%
data['Total_Stops'] = data['Total_Stops'].map(stop)

# %%
data['Total_Stops']
# Out:
# 0        0
# 1        2
# 2        2
# 3        1
# 4        1
#         ..
# 10678    0
# 10679    0
# 10680    0
# 10681    0
# 10682    2
# Name: Total_Stops, Length: 10682, dtype: int64

# %% [markdown]
# ###  Eliminate irrelevant features from the dataset.

# %%
data.head(1)
# Out:
#    Airline Date_of_Journey    Source  Destination      Route Duration  \
# 0        3      2019-03-24  Banglore            2  BLR → DEL   2h 50m
#
#    Total_Stops Additional_Info  Price  Journey_day  ...  Arrival_Time_hour  \
# 0            0         No info   3897           24  ...                  1
#
#    Arrival_Time_minute  Duration_hours  Duration_mins  Duration_total_mins  \
# 0                   10               2             50                  170
#
#    Source_Banglore  Source_Kolkata  Source_Delhi  Source_Chennai  \
# 0                1               0             0               0
#
#    Source_Mumbai
# 0              0
#
# [1 rows x 24 columns]

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Duration', 'Total_Stops', 'Additional_Info', 'Price', 'Journey_day',
#        'Journey_month', 'Journey_year', 'Dep_Time_hour', 'Dep_Time_minute',
#        'Arrival_Time_hour', 'Arrival_Time_minute', 'Duration_hours',
#        'Duration_mins', 'Duration_total_mins', 'Source_Banglore',
#        'Source_Kolkata', 'Source_Delhi', 'Source_Chennai', 'Source_Mumbai'],
#       dtype='object')

# %%
data['Additional_Info'].value_counts()/len(data)*100
# Out:
# Additional_Info
# No info                         78.112713
# In-flight meal not included     18.554578
# No check-in baggage included     2.995694
# 1 Long layover                   0.177869
# Change airports                  0.065531
# Business class                   0.037446
# No Info                          0.028085
# 1 Short layover                  0.009362
# Red-eye flight                   0.009362
# 2 Long layover                   0.009362
# Name: count, dtype: float64

# %%
data.head(4)
# Out:
#    Airline Date_of_Journey    Source  Destination                  Route  \
# 0        3      2019-03-24  Banglore            2              BLR → DEL
# 1        7      2019-05-01   Kolkata            3  CCU → IXR → BBI → BLR
# 2       10      2019-06-09     Delhi            4  DEL → LKO → BOM → COK
# 3        3      2019-05-12   Kolkata            3        CCU → NAG → BLR
#
#   Duration  Total_Stops Additional_Info  Price  Journey_day  ...  \
# 0   2h 50m            0         No info   3897           24  ...
# 1   7h 25m            2         No info   7662            1  ...
# 2   19h 0m            2         No info  13882            9  ...
# 3   5h 25m            1         No info   6218           12  ...
#
#    Arrival_Time_hour  Arrival_Time_minute  Duration_hours  Duration_mins  \
# 0                  1                   10               2             50
# 1                 13                   15               7             25
# ...

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Duration', 'Total_Stops', 'Additional_Info', 'Price', 'Journey_day',
#        'Journey_month', 'Journey_year', 'Dep_Time_hour', 'Dep_Time_minute',
#        'Arrival_Time_hour', 'Arrival_Time_minute', 'Duration_hours',
#        'Duration_mins', 'Duration_total_mins', 'Source_Banglore',
#        'Source_Kolkata', 'Source_Delhi', 'Source_Chennai', 'Source_Mumbai'],
#       dtype='object')

# %%
data['Journey_year'].unique()

#   Unique values present in the 'Journey_year' column
# Out:
# array([2019])

# %%
data.drop(columns=['Date_of_Journey' , 'Additional_Info' , 'Duration_total_mins' , 'Source' , 'Journey_year'] , axis=1 , inplace=True)

# %%
data.columns
# Out:
# Index(['Airline', 'Destination', 'Route', 'Duration', 'Total_Stops', 'Price',
#        'Journey_day', 'Journey_month', 'Dep_Time_hour', 'Dep_Time_minute',
#        'Arrival_Time_hour', 'Arrival_Time_minute', 'Duration_hours',
#        'Duration_mins', 'Source_Banglore', 'Source_Kolkata', 'Source_Delhi',
#        'Source_Chennai', 'Source_Mumbai'],
#       dtype='object')

# %%
data.head(4)
# Out:
#    Airline  Destination                  Route Duration  Total_Stops  Price  \
# 0        3            2              BLR → DEL   2h 50m            0   3897
# 1        7            3  CCU → IXR → BBI → BLR   7h 25m            2   7662
# 2       10            4  DEL → LKO → BOM → COK   19h 0m            2  13882
# 3        3            3        CCU → NAG → BLR   5h 25m            1   6218
#
#    Journey_day  Journey_month  Dep_Time_hour  Dep_Time_minute  \
# 0           24              3             22               20
# 1            1              5              5               50
# 2            9              6              9               25
# 3           12              5             18                5
#
#    Arrival_Time_hour  Arrival_Time_minute  Duration_hours  Duration_mins  \
# 0                  1                   10               2             50
# 1                 13                   15               7             25
# ...

# %%
#  We can also drop the "Route" feature since it is directly related to the "Total stops."
#  Including both features would be redundant when building the ML model.

data.drop(columns=['Route'] , axis=1 , inplace=True)

# %%
data.head(3)
# Out:
#    Airline  Destination Duration  Total_Stops  Price  Journey_day  \
# 0        3            2   2h 50m            0   3897           24
# 1        7            3   7h 25m            2   7662            1
# 2       10            4   19h 0m            2  13882            9
#
#    Journey_month  Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  \
# 0              3             22               20                  1
# 1              5              5               50                 13
# 2              6              9               25                  4
#
#    Arrival_Time_minute  Duration_hours  Duration_mins  Source_Banglore  \
# 0                   10               2             50                1
# 1                   15               7             25                0
# 2                   25              19              0                0
#
#    Source_Kolkata  Source_Delhi  Source_Chennai  Source_Mumbai
# 0               0             0               0              0
# ...

# %%
## We can drop the "Duration" feature since we have already extracted the "Duration hour" and "Duration minute" features.

data.drop(columns=['Duration'] , axis=1 , inplace=True)

# %%
data.head(3)
# Out:
#    Airline  Destination  Total_Stops  Price  Journey_day  Journey_month  \
# 0        3            2            0   3897           24              3
# 1        7            3            2   7662            1              5
# 2       10            4            2  13882            9              6
#
#    Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  Arrival_Time_minute  \
# 0             22               20                  1                   10
# 1              5               50                 13                   15
# 2              9               25                  4                   25
#
#    Duration_hours  Duration_mins  Source_Banglore  Source_Kolkata  \
# 0               2             50                1               0
# 1               7             25                0               1
# 2              19              0                0               0
#
#    Source_Delhi  Source_Chennai  Source_Mumbai
# 0             0               0              0
# ...

# %% [markdown]
# ##  Detecting Outliers

# %% [markdown]
# #### Visualization plots to identify  the outliers.
#     Box Plot: Identifies outliers outside the "whiskers."
#     Histogram: Shows bars far from the main distribution as potential outliers.
#     Scatter Plot: Outliers appear as points far from clusters.
#     Violin Plot: Shows distribution; outliers are outside the main body.
#     Pair Plot: Spot outliers across multiple variables.

# %%
def plot(df, col):
    fig , (ax1 , ax2 , ax3) = plt.subplots(3,1)
    
    sns.distplot(df[col] , ax=ax1)
    sns.boxplot(df[col] , ax=ax2)
    sns.distplot(df[col] , ax=ax3 , kde=False)

# %% [markdown]
# ## Calculate the IQR (difference between 75th and 25th percentiles).
#      Find the upper and lower bounds using the formula:
#      Lower Bound = 25th percentile - 1.5 × IQR
#      Upper Bound = 75th percentile + 1.5 × IQR
#      Any data point outside these bounds is an outlier.

# %%
q1 = data['Price'].quantile(0.25)
q3 = data['Price'].quantile(0.75)

iqr = q3- q1

maximum = q3 + 1.5*iqr
minimum = q1 - 1.5*iqr

# %%
print(maximum)
# Out:
# 23017.0

# %%
print(minimum)
# Out:
# -5367.0

# %%
print([price for price in data['Price'] if price> maximum or price<minimum])
# Out:
# [27430, 36983, 26890, 26890, 25139, 27210, 52229, 26743, 26890, 25735, 27992, 26890, 26890, 23583, 26890, 23533, 24115, 25735, 54826, 31783, 27992, 26890, 26890, 25430, 36235, 27210, 26890, 25735, 54826, 26890, 35185, 79512, 28097, 27992, 26890, 25735, 26092, 31825, 25913, 25735, 27992, 31825, 23267, 62427, 54826, 31825, 25430, 26890, 36235, 23843, 26890, 25735, 28322, 25735, 25735, 31825, 26890, 27992, 34273, 46490, 29528, 26890, 26890, 26890, 34503, 26890, 27992, 26890, 26890, 23170, 24528, 26890, 27992, 25735, 34608, 25703, 26890, 23528, 31825, 27282, 25735, 27992, 52285, 24017, 31945, 26890, 24318, 23677, 27992, 24210, 57209, 26890, 31825, 26480]

# %%
len([price for price in data['Price'] if price> maximum or price<minimum])
# Out:
# 94

# %% [markdown]
# ### Deal with Outlier.

# %%
## This is a way to handle outliers in your dataset, especially when values are abnormally high.
##  Replacing values greater than a certain threshold with the median makes the data less skewed and can improve model performance.

data['Price'] = np.where(data['Price']>=35000 , data['Price'].median() , data['Price'])

# %%
plot(data , 'Price')

# %% [markdown]
# ## Feature selection

# %%
X = data.drop(['Price'] , axis=1)

#  It separates the features (input variables) from the target variable (Price), preparing the dataset for machine learning.

# %%
y = data['Price']

# %%
from sklearn.feature_selection import mutual_info_regression

# %%
imp = mutual_info_regression(X , y)

# %%
imp
# Out:
# array([1.3207185 , 1.06252026, 0.78741095, 0.36779786, 0.62743374,
#        0.9251    , 0.7550885 , 1.14780182, 0.89980668, 1.12224269,
#        0.67859958, 0.38595818, 0.46153562, 0.51697882, 0.13357034,
#        0.2004914 ])

# %%
imp_df = pd.DataFrame(imp , index=X.columns)

# %%
imp_df.columns = ['importance']

# %%
imp_df
# Out:
#                      importance
# Airline                1.320718
# Destination            1.062520
# Total_Stops            0.787411
# Journey_day            0.367798
# Journey_month          0.627434
# Dep_Time_hour          0.925100
# Dep_Time_minute        0.755088
# Arrival_Time_hour      1.147802
# Arrival_Time_minute    0.899807
# Duration_hours         1.122243
# Duration_mins          0.678600
# Source_Banglore        0.385958
# Source_Kolkata         0.461536
# Source_Delhi           0.516979
# Source_Chennai         0.133570
# Source_Mumbai          0.200491

# %%
imp_df.sort_values(by='importance' , ascending=False)
# Out:
#                      importance
# Airline                1.320718
# Arrival_Time_hour      1.147802
# Duration_hours         1.122243
# Destination            1.062520
# Dep_Time_hour          0.925100
# Arrival_Time_minute    0.899807
# Total_Stops            0.787411
# Dep_Time_minute        0.755088
# Duration_mins          0.678600
# Journey_month          0.627434
# Source_Delhi           0.516979
# Source_Kolkata         0.461536
# Source_Banglore        0.385958
# Journey_day            0.367798
# Source_Mumbai          0.200491
# Source_Chennai         0.133570

# %% [markdown]
# #  Split dataset into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
   X, y, test_size=0.25, random_state=42)

# %% [markdown]
# #  CatBoost Model used along with others

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
import xgboost as xgb
import lightgbm as lgb
import catboost as cb
from sklearn.linear_model import Lasso
from sklearn import metrics

# %% [markdown]
# # Define Models

# %%
# Define Models
models = {
    "RandomForestRegressor": RandomForestRegressor(n_estimators=400, max_depth=None, min_samples_split=5, random_state=42),
    "XGBRegressor": xgb.XGBRegressor(),
    "LightGBM": lgb.LGBMRegressor(),
    "CatBoost": cb.CatBoostRegressor(silent=True),
    "GradientBoostingRegressor": GradientBoostingRegressor(),
    "ExtraTreesRegressor": ExtraTreesRegressor(),
    "LassoRegression": Lasso()
}

# %% [markdown]
# # Initialize results table

# %%
Results = pd.DataFrame(columns=[
    "Model Name", "R2 Score", "MAE", "MSE", "RMSE", "Adj R2 Score", "MAPE", "RMSLE"
])

# Define function to compute MAPE
def MAPE(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Train & Evaluate Each Model
for name, model in models.items():
    model.fit(X_train, y_train)  # Train model
    y_pred = model.predict(X_test)  # Make predictions
    
    # Compute Metrics
    mae = metrics.mean_absolute_error(y_test, y_pred)
    mse = metrics.mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = metrics.r2_score(y_test, y_pred)
    mape = MAPE(y_test, y_pred)
    rmsle = np.log(rmse) if rmse > 0 else 0
    
    # Adjusted R2 Score Calculation
    n = len(y_test)
    p = X_test.shape[1]
    adj_r2 = 1 - (1 - r2) * (n - 1) / (n - p - 1)

    # Append results to DataFrame
    Results.loc[len(Results)] = [name, r2, mae, mse, rmse, adj_r2, mape, rmsle]

    # Display Model Performance
    print(f"\nModel: {name} (R2 Score: {r2:.4f})")
    print(f"MAE: {mae:.4f}")
    print(f"MSE: {mse:.4f}")
    print(f"RMSE: {rmse:.4f}")
    print(f"Adjusted R2 Score: {adj_r2:.4f}")
    print(f"MAPE: {mape:.2f}%")
    print(f"RMSLE: {rmsle:.4f}")
    print('-' * 80)
# Out:
# Model: RandomForestRegressor (R2 Score: 0.8216)
# MAE: 1146.0320
# MSE: 3473334.0432
# RMSE: 1863.6883
# Adjusted R2 Score: 0.8205
# MAPE: 12.83%
# RMSLE: 7.5303
# --------------------------------------------------------------------------------
#
# Model: XGBRegressor (R2 Score: 0.8337)
# MAE: 1146.5763
# MSE: 3236618.7974
# RMSE: 1799.0605
# Adjusted R2 Score: 0.8327
# MAPE: 13.02%
# RMSLE: 7.4950
# --------------------------------------------------------------------------------
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000463 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 172
# [LightGBM] [Info] Number of data points in the train set: 8011, number of used features: 16
# [LightGBM] [Info] Start training from score 9040.135688
#
# Model: LightGBM (R2 Score: 0.8311)
# MAE: 1221.1643
# MSE: 3288000.7557
# RMSE: 1813.2845
# ...

# %% [markdown]
# # Display results table

# %%
print("\nFinal Model Performance Table:")
print(Results)
# Out:
# Final Model Performance Table:
#                   Model Name  R2 Score          MAE           MSE  \
# 0      RandomForestRegressor  0.821584  1146.031983  3.473334e+06
# 1               XGBRegressor  0.833743  1146.576268  3.236619e+06
# 2                   LightGBM  0.831104  1221.164286  3.288001e+06
# 3                   CatBoost  0.841743  1169.339961  3.080890e+06
# 4  GradientBoostingRegressor  0.757199  1528.747695  4.726760e+06
# 5        ExtraTreesRegressor  0.784966  1217.312396  4.186193e+06
# 6            LassoRegression  0.571119  2013.720489  8.349281e+06
#
#           RMSE  Adj R2 Score       MAPE     RMSLE
# 0  1863.688290      0.820508  12.826488  7.530313
# 1  1799.060532      0.832741  13.022284  7.495020
# 2  1813.284521      0.830086  14.107749  7.502895
# 3  1755.246547      0.840789  13.295123  7.470365
# 4  2174.111300      0.755735  17.916577  7.684375
# 5  2046.018761      0.783670  13.770410  7.623651
# 6  2889.512178      0.568534  24.887266  7.968843

# %% [markdown]
# # Plot actual vs predicted values for the best model (highest R2)

# %%
best_model_name = Results.loc[Results['R2 Score'].idxmax(), "Model Name"]
best_model = models[best_model_name]
y_pred_best = best_model.predict(X_test)

plt.figure(figsize=(8,6))
sns.scatterplot(x=y_test, y=y_pred_best)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title(f"Actual vs Predicted Prices ({best_model_name})")
plt.show()

# %% [markdown]
# #  Random Forest Model without Hyperparameter Tuning

# %%
def predict(model):
    print('Training score : {}'.format(model.score(X_train, y_train)))
    y_prediction = model.predict(X_test)
    print('Predictions are : {}'.format(y_prediction))
    print('\n')
    
  

    # Calculate R2 score and convert it to percentage
    r2_score_val = metrics.r2_score(y_test, y_prediction)
    r2_percentage = r2_score_val * 100  # Convert to percentage
    
    # Print R2 as percentage
    print('R2 score (percentage) : {:.2f}'.format(r2_percentage))
    
    # r2_score = metrics.r2_score(y_test, y_prediction)
    # print('R2 score : {}'.format(r2_score))
    print('MAE : {}'.format(metrics.mean_absolute_error(y_test, y_prediction)))
    print('MSE : {}'.format(metrics.mean_squared_error(y_test, y_prediction)))
    print('RMSE : {}'.format(np.sqrt(metrics.mean_squared_error(y_test, y_prediction))))
    print('MAPE : {}'.format(MAPE(y_test, y_prediction)))
    sns.distplot(y_test - y_prediction)

# Train the model only once
optimized_model  = RandomForestRegressor(
    n_estimators=400,
    max_depth=None,
    min_samples_split=5,
    random_state=42
)
optimized_model .fit(X_train, y_train)

# Call the function with the trained model
predict(optimized_model )
# Out:
# Training score : 0.9365348105345408
# Predictions are : [16864.93445139  5262.6469403   8780.70223972 ...  3561.90827165
#   6632.54962491  6871.13909434]
#
#
# R2 score (percentage) : 82.16
# MAE : 1146.0319833392678
# MSE : 3473334.04316612
# RMSE : 1863.6882902368948
# MAPE : 12.826487616447208

# %% [markdown]
# # Random Forest Model without Hyperparameter Tuning

# %%
def predict(ml_model):
    model = ml_model.fit(X_train , y_train)
    print('Training score : {}'.format(model.score(X_train , y_train)))
    y_predection = model.predict(X_test)
    print('predictions are : {}'.format(y_predection))
    print('\n')
    r2_score = metrics.r2_score(y_test , y_predection)
    print('r2 score : {}'.format(r2_score))
    print('MAE : {}'.format(metrics.mean_absolute_error(y_test , y_predection)))
    print('MSE : {}'.format(metrics.mean_squared_error(y_test , y_predection)))
    print('RMSE : {}'.format(np.sqrt(metrics.mean_squared_error(y_test , y_predection))))
    print('MAPE : {}'.format(MAPE(y_test , y_predection)))
    sns.distplot(y_test - y_predection)

# %%
predict(RandomForestRegressor())
# Out:
# Training score : 0.9514504599559604
# predictions are : [16703.27  5473.35  8824.8  ...  3538.33  6353.69  6785.55]
#
#
# r2 score : 0.8128736605214926
# MAE : 1174.0894376720662
# MSE : 3642900.663824959
# RMSE : 1908.638431926005
# MAPE : 13.184265855839685

# %% [markdown]
# # Actual vs Predicted Prices (Line Graph)

# %%
import numpy as np
import matplotlib.pyplot as plt

y_pred = optimized_model.predict(X_test)
# Sorting values for better visualization
y_test_sorted = np.sort(y_test.values)
y_pred_sorted = np.sort(y_pred)

# Line plot
plt.figure(figsize=(5, 3))
plt.plot(y_test_sorted, label="Actual Price", color="blue", marker="o", linestyle="-")
plt.plot(y_pred_sorted, label="Predicted Price", color="red", marker="x", linestyle="--")
plt.xlabel("Index")
plt.ylabel("Price")
plt.title("Actual vs Predicted Prices (Line Graph)")
plt.legend()
plt.show()

# %%
y_pred_optimized = optimized_model.predict(X_test)

# Train and predict using the default model
default_model = RandomForestRegressor()  # Default parameters
default_model.fit(X_train, y_train)
y_pred_default = default_model.predict(X_test)

# %% [markdown]
# # Select the first 50 observations

# %%
num_observations = 50
y_test_sample = np.array(y_test)[:num_observations]
y_pred_optimized_sample = y_pred_optimized[:num_observations]
y_pred_default_sample = y_pred_default[:num_observations]

# Plot line graph
plt.figure(figsize=(12, 3))

plt.plot(y_test_sample, label="Actual Prices", color="black", linewidth=2, marker="o")
plt.plot(y_pred_optimized_sample, label="Optimized Model Predictions", color="blue", linestyle="dashed", linewidth=2, marker="s")
plt.plot(y_pred_default_sample, label="Default Model Predictions", color="red", linestyle="dashed", linewidth=2, marker="^")

plt.xlabel("Number of Observations (First 50)")
plt.ylabel("Flight Price")
plt.title("Actual vs Predicted Prices (First 50 Observations)")
plt.legend()
plt.grid(True)
plt.show()

# %%
#  Select random  50 observations

# %%
random_indices = np.random.choice(len(y_test), 30, replace=False)
y_test_sample = np.array(y_test)[random_indices]
y_pred_optimized_sample = y_pred_optimized[random_indices]
y_pred_default_sample = y_pred_default[random_indices]

# Plot line graph
plt.figure(figsize=(12, 3))

plt.plot(y_test_sample, label="Actual Prices", color="black", linewidth=2, marker="o")
plt.plot(y_pred_optimized_sample, label="Optimized Model Predictions", color="blue", linestyle="dashed", linewidth=2, marker="s")
plt.plot(y_pred_default_sample, label="Default Model Predictions", color="red", linestyle="dashed", linewidth=2, marker="^")

plt.xlabel("Random 30 Observations")
plt.ylabel("Flight Price")
plt.title("Actual vs Predicted Prices (Random 30 Observations)")
plt.legend()
plt.grid(True)
plt.show()
